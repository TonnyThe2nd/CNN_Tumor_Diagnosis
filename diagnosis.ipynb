# %%
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.image import resize

imagem = './Testing/pituitary_tumor/image.jpg'

img = load_img(imagem)

img_array = img_to_array(img)

img_ajustada = resize(img_array, (128,128))

img = img_ajustada / 255
import numpy as np

img = np.expand_dims(img, axis=0)

from tensorflow.keras.models import load_model

model = load_model('cnn_tumor_02.h5')

result = model.predict(img)

indice = result.argmax()
display(indice)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step
# array([[2.9958622e-04, 2.6631765e-03, 1.6959324e-04, 9.9686760e-01]],
#       dtype=float32)
# 3
