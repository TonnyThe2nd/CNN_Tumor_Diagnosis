# %%
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.image import resize

imagem = './Testing/glioma_tumor/image.jpg'

img = load_img(imagem)

img_array = img_to_array(img)

img_ajustada = resize(img_array, (128,128))

img = img_ajustada / 255
import numpy as np

img = np.expand_dims(img, axis=0)

from tensorflow.keras.models import load_model

model = load_model('cnn_tumor.h5')

model.predict(img)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 5
#       1 from tensorflow.keras.preprocessing.image import load_img, img_to_array
#       3 imagem = './Testing/glioma_tumor/image.jpg'
# ----> 5 img = load_img(imagem, (128,128))
#       7 img_array = img_to_array(img)/255
#       9 import numpy as np
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\utils\image_utils.py:254, in load_img(path, color_mode, target_size, interpolation, keep_aspect_ratio)
#     252         img = img.convert("RGB")
#     253 else:
# --> 254     raise ValueError('color_mode must be "grayscale", "rgb", or "rgba"')
#     255 if target_size is not None:
#     256     width_height_tuple = (target_size[1], target_size[0])
#
# ValueError: color_mode must be "grayscale", "rgb", or "rgba"
